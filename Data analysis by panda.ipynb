# %%
import pandas as pd

# %%
# Importing files

excel_file_path = r'E:\data source\Nike Dataset.xlsx'
df = pd.read_excel(excel_file_path)

# %%
# How many rows & columns
df.shape
# Out:
# (9648, 13)

# %%
# Understanding data using .info()
# The .info() method is a quick way to look at the data types,
# missing values, and data size of a DataFrame.
# Here, we’re setting the show_counts argument to True, 
# which gives a few over the total non-missing values in each column. 
# We’re also setting memory_usage to True,
# which shows the total memory usage of the DataFrame elements.
# When verbose is set to True, it prints the full summary from .info(). 

df.info(show_counts=True, memory_usage=True, verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9648 entries, 0 to 9647
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          9648 non-null   object
#  1   Retailer ID       9648 non-null   int64
#  2   Invoice Date      9648 non-null   datetime64[ns]
#  3   Region            9648 non-null   object
#  4   State             9648 non-null   object
#  5   City              9648 non-null   object
#  6   Product           9648 non-null   object
#  7   Price per Unit    9648 non-null   float64
#  8   Units Sold        9648 non-null   int64
#  9   Total Sales       9648 non-null   float64
#  10  Operating Profit  9648 non-null   float64
#  11  Operating Margin  9648 non-null   float64
#  12  Sales Method      9648 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(6)
# memory usage: 980.0+ KB

# %%
# Get all columns and column names
# Calling the .columns attribute of a DataFrame object returns the column names 
# in the form of an Index object. 
# As a reminder, a pandas index is the address/label of the row or column.

df.columns
# Out:
# Index(['Retailer', 'Retailer ID', 'Invoice Date', 'Region', 'State', 'City',
#        'Product', 'Price per Unit', 'Units Sold', 'Total Sales',
#        'Operating Profit', 'Operating Margin', 'Sales Method'],
#       dtype='object')

# %%
# It can be converted to a list using a list() function.

list(df.columns)
# Out:
# ['Retailer',
#  'Retailer ID',
#  'Invoice Date',
#  'Region',
#  'State',
#  'City',
#  'Product',
#  'Price per Unit',
#  'Units Sold',
#  'Total Sales',
#  'Operating Profit',
#  'Operating Margin',
#  'Sales Method']

# %%
# Checking for missing values in pandas with .isnull()
# The sample DataFrame does not have any missing values. 
# Let's introduce a few to make things interesting.
# The .copy() method makes a copy of the original DataFrame.
# This is done to ensure that any changes to the copy don’t reflect in the original DataFrame.
# Using .loc (to be discussed later), you can set rows two to five of the Pregnancies column
# to NaN values, which denote missing values.

df2 = df.copy()
df2.loc[2:5,'Pregnancies'] = None
df2.head(3)
# Out:
#       Retailer  Retailer ID Invoice Date     Region     State      City  ...  \
# 0  Foot Locker      1185732   2020-01-01  Northeast  New York  New York  ...
# 1  Foot Locker      1185732   2020-01-02  Northeast  New York  New York  ...
# 2  Foot Locker      1185732   2020-01-03  Northeast  New York  New York  ...
#
#   Units Sold  Total Sales  Operating Profit  Operating Margin  Sales Method  \
# 0       1200     600000.0          300000.0              0.50      In-store
# 1       1000     500000.0          150000.0              0.30      In-store
# 2       1000     400000.0          140000.0              0.35      In-store
#
#    Pregnancies
# 0          NaN
# 1          NaN
# 2          NaN
#
# [3 rows x 14 columns]

# %%
# How to view data using .head() and .tail()
# You can view the first few or last few rows of a DataFrame using the .head() or .tail() methods
# respectively You can specify the number of rows through the n argument 
# (the default value is 5).

# %%
#First five rows of the DataFrame 
print(df.head(5))
# Out:
#       Retailer  Retailer ID Invoice Date     Region     State      City  \
# 0  Foot Locker      1185732   2020-01-01  Northeast  New York  New York
# 1  Foot Locker      1185732   2020-01-02  Northeast  New York  New York
# 2  Foot Locker      1185732   2020-01-03  Northeast  New York  New York
# 3  Foot Locker      1185732   2020-01-04  Northeast  New York  New York
# 4  Foot Locker      1185732   2020-01-05  Northeast  New York  New York
#
#                      Product  Price per Unit  Units Sold  Total Sales  \
# 0      Men's Street Footwear            50.0        1200     600000.0
# 1    Men's Athletic Footwear            50.0        1000     500000.0
# 2    Women's Street Footwear            40.0        1000     400000.0
# 3  Women's Athletic Footwear            45.0         850     382500.0
# 4              Men's Apparel            60.0         900     540000.0
#
#    Operating Profit  Operating Margin Sales Method
# 0          300000.0              0.50     In-store
# ...

# %%
# Last five rows of the DataFrame 
df.tail(n = 5)
# Out:
#          Retailer  Retailer ID Invoice Date     Region          State  \
# 9643  Foot Locker      1185732   2021-01-24  Northeast  New Hampshire
# 9644  Foot Locker      1185732   2021-01-24  Northeast  New Hampshire
# 9645  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
# 9646  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
# 9647  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
#
#             City                  Product  Price per Unit  Units Sold  \
# 9643  Manchester            Men's Apparel            50.0          64
# 9644  Manchester          Women's Apparel            41.0         105
# 9645  Manchester    Men's Street Footwear            41.0         184
# 9646  Manchester  Men's Athletic Footwear            42.0          70
# 9647  Manchester  Women's Street Footwear            29.0          83
#
#       Total Sales  Operating Profit  Operating Margin Sales Method
# ...

# %%
df
# Out:
#          Retailer  Retailer ID Invoice Date     Region          State  \
# 0     Foot Locker      1185732   2020-01-01  Northeast       New York
# 1     Foot Locker      1185732   2020-01-02  Northeast       New York
# 2     Foot Locker      1185732   2020-01-03  Northeast       New York
# 3     Foot Locker      1185732   2020-01-04  Northeast       New York
# 4     Foot Locker      1185732   2020-01-05  Northeast       New York
# ...           ...          ...          ...        ...            ...
# 9643  Foot Locker      1185732   2021-01-24  Northeast  New Hampshire
# 9644  Foot Locker      1185732   2021-01-24  Northeast  New Hampshire
# 9645  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
# 9646  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
# 9647  Foot Locker      1185732   2021-02-22  Northeast  New Hampshire
#
#             City                    Product  Price per Unit  Units Sold  \
# ...

# %%
# Get summary statistics with .describe()

# Understanding data using .describe()
# The describe() method prints the summary statistics of all numeric columns,
# such as count, mean, standard deviation, range, and quartiles of numeric columns.
df.describe()
# Out:
#         Retailer ID  Price per Unit   Units Sold    Total Sales  \
# count  9.648000e+03     9648.000000  9648.000000    9648.000000
# mean   1.173850e+06       45.216625   256.930037   93273.437500
# std    2.636038e+04       14.705397   214.252030  141916.016727
# min    1.128299e+06        7.000000     0.000000       0.000000
# 25%    1.185732e+06       35.000000   106.000000    4254.500000
# 50%    1.185732e+06       45.000000   176.000000    9576.000000
# 75%    1.185732e+06       55.000000   350.000000  150000.000000
# max    1.197831e+06      110.000000  1275.000000  825000.000000
#
#        Operating Profit  Operating Margin
# count       9648.000000       9648.000000
# mean       34425.244761          0.422991
# std        54193.113713          0.097197
# min            0.000000          0.100000
# 25%         1921.752500          0.350000
# 50%         4371.420000          0.410000
# 75%        52062.500000          0.490000
# max       390000.000000          0.800000

# %%
# Get summary statistics of integer columns only 

df.describe(include=[int])
# Out:
#         Retailer ID   Units Sold
# count  9.648000e+03  9648.000000
# mean   1.173850e+06   256.930037
# std    2.636038e+04   214.252030
# min    1.128299e+06     0.000000
# 25%    1.185732e+06   106.000000
# 50%    1.185732e+06   176.000000
# 75%    1.185732e+06   350.000000
# max    1.197831e+06  1275.000000

# %%
# Get summary statistics of non-integer columns only 

df.describe(exclude=[int])
# Out:
# C:\Users\NOUR SOFT\AppData\Local\Temp\ipykernel_948\1654552041.py:3: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(exclude=[int])
#            Retailer         Invoice Date Region       State      City  \
# count          9648                 9648   9648        9648      9648
# unique            6                  724      5          50        52
# top     Foot Locker  2021-01-17 00:00:00   West  California  Portland
# freq           2637                   77   2448         432       360
# first           NaN  2020-01-01 00:00:00    NaN         NaN       NaN
# last            NaN  2021-12-31 00:00:00    NaN         NaN       NaN
# mean            NaN                  NaN    NaN         NaN       NaN
# std             NaN                  NaN    NaN         NaN       NaN
# ...

# %%
# Transpose summary statistics with .T

df.describe().T
# Out:
#                    count          mean            std        min  \
# Retailer ID       9648.0  1.173850e+06   26360.377309  1128299.0
# Price per Unit    9648.0  4.521663e+01      14.705397        7.0
# Units Sold        9648.0  2.569300e+02     214.252030        0.0
# Total Sales       9648.0  9.327344e+04  141916.016727        0.0
# Operating Profit  9648.0  3.442524e+04   54193.113713        0.0
# Operating Margin  9648.0  4.229913e-01       0.097197        0.1
#
#                            25%         50%         75%        max
# Retailer ID       1.185732e+06  1185732.00  1185732.00  1197831.0
# Price per Unit    3.500000e+01       45.00       55.00      110.0
# Units Sold        1.060000e+02      176.00      350.00     1275.0
# Total Sales       4.254500e+03     9576.00   150000.00   825000.0
# Operating Profit  1.921753e+03     4371.42    52062.50   390000.0
# Operating Margin  3.500000e-01        0.41        0.49        0.8

# %%
# Slicing and Extracting Data in pandas

# %%
# Isolating one column using [ ]  
# You can isolate a single column using a square bracket [ ] with a column name in it. 
# The output is a pandas Series object. 
# A pandas Series is a one-dimensional array containing data of any type, 
# including integer, float, string, boolean, python objects, etc. 
# A DataFrame is comprised of many series that act as columns.

df['Operating Profit']
# Out:
# 0       300000.00
# 1       150000.00
# 2       140000.00
# 3       133875.00
# 4       162000.00
#           ...
# 9643       896.00
# 9644      1377.60
# 9645      2791.28
# 9646      1234.80
# 9647       649.89
# Name: Operating Profit, Length: 9648, dtype: float64

# %%
# Isolating two or more columns using [[ ]] 
# You can also provide a list of column names inside the square brackets to fetch more than one column.
# Here, square brackets are used in two different ways.
# We use the outer square brackets to indicate a subset of a DataFrame, 
# and the inner square brackets to create a list.

df[['Region','Operating Profit']]
# Out:
#          Region  Operating Profit
# 0     Northeast         300000.00
# 1     Northeast         150000.00
# 2     Northeast         140000.00
# 3     Northeast         133875.00
# 4     Northeast         162000.00
# ...         ...               ...
# 9643  Northeast            896.00
# 9644  Northeast           1377.60
# 9645  Northeast           2791.28
# 9646  Northeast           1234.80
# 9647  Northeast            649.89
#
# [9648 rows x 2 columns]

# %%
# Isolating one row using [ ] 
# A single row can be fetched by passing in a boolean series with one True value. In the example below, the second row with index = 1 is returned. Here, .index returns the row labels of the DataFrame,
# and the comparison turns that into a Boolean one-dimensional array.

df[df.index==1]
# Out:
#       Retailer  Retailer ID Invoice Date     Region     State      City  \
# 1  Foot Locker      1185732   2020-01-02  Northeast  New York  New York
#
#                    Product  Price per Unit  Units Sold  Total Sales  \
# 1  Men's Athletic Footwear            50.0        1000     500000.0
#
#    Operating Profit  Operating Margin Sales Method
# 1          150000.0               0.3     In-store

# %%
# Isolating two or more rows using [ ] 
# Similarly, two or more rows can be returned using the .
# isin() method instead of a == operator.

df[df.index.isin(range(2,5))]
# Out:
#       Retailer  Retailer ID Invoice Date     Region     State      City  \
# 2  Foot Locker      1185732   2020-01-03  Northeast  New York  New York
# 3  Foot Locker      1185732   2020-01-04  Northeast  New York  New York
# 4  Foot Locker      1185732   2020-01-05  Northeast  New York  New York
#
#                      Product  Price per Unit  Units Sold  Total Sales  \
# 2    Women's Street Footwear            40.0        1000     400000.0
# 3  Women's Athletic Footwear            45.0         850     382500.0
# 4              Men's Apparel            60.0         900     540000.0
#
#    Operating Profit  Operating Margin Sales Method
# 2          140000.0              0.35     In-store
# 3          133875.0              0.35     In-store
# 4          162000.0              0.30     In-store

# %%
# Using .loc[] and .iloc[] to fetch rows
# The below example returns a pandas Series instead of a DataFrame.
# The 1 represents the row index (label),
# whereas the 1 in .iloc[] is the row position (first row).

df2.loc[1]
# Out:
# Retailer                    Foot Locker
# Retailer ID                     1185732
# Invoice Date        2020-01-02 00:00:00
# Region                        Northeast
# State                          New York
#                            ...
# Total Sales                    500000.0
# Operating Profit               150000.0
# Operating Margin                    0.3
# Sales Method                   In-store
# Pregnancies                         NaN
# Name: 1, Length: 14, dtype: object

# %%
# You can also fetch multiple rows by providing a range in square brackets

df2.loc[100:105]
# Out:
#     Retailer  Retailer ID Invoice Date Region  State     City  ... Units Sold  \
# 100  Walmart      1197831   2020-08-20  South  Texas  Houston  ...        800
# 101  Walmart      1197831   2020-08-21  South  Texas  Houston  ...        750
# 102  Walmart      1197831   2020-08-22  South  Texas  Houston  ...        650
# 103  Walmart      1197831   2020-08-23  South  Texas  Houston  ...       1000
# 104  Walmart      1197831   2020-08-24  South  Texas  Houston  ...        950
# 105  Walmart      1197831   2020-08-25  South  Texas  Houston  ...        950
#
#      Total Sales  Operating Profit  Operating Margin  Sales Method  \
# 100     320000.0          112000.0              0.35        Outlet
# 101     300000.0          135000.0              0.45        Outlet
# 102     292500.0           87750.0              0.30        Outlet
# 103     500000.0          250000.0              0.50        Outlet
# 104     380000.0          133000.0              0.35        Outlet
# ...

# %%
# You can also subset with .loc[] and .
# iloc[] by using a list instead of a range.

df2.loc[[100, 200, 300]]
# Out:
#         Retailer  Retailer ID Invoice Date   Region       State  \
# 100      Walmart      1197831   2020-08-20    South       Texas
# 200    West Gear      1128299   2021-02-05     West  California
# 300  Foot Locker      1185732   2021-06-16  Midwest    Illinois
#
#               City  ... Units Sold  Total Sales  Operating Profit  \
# 100        Houston  ...        800     320000.0          112000.0
# 200  San Francisco  ...        875     481250.0          144375.0
# 300        Chicago  ...        125      75000.0           26250.0
#
#      Operating Margin  Sales Method  Pregnancies
# 100              0.35        Outlet          NaN
# 200              0.30        Outlet          NaN
# 300              0.35        Outlet          NaN
#
# [3 rows x 14 columns]

# %%
# You can also select specific columns along with rows. This is where .
# iloc[] is different from .
# loc[] – it requires column location and not column labels.

df2.loc[100:105, ['Region','Operating Profit', 'Units Sold']]
# Out:
#     Region  Operating Profit  Units Sold
# 100  South          112000.0         800
# 101  South          135000.0         750
# 102  South           87750.0         650
# 103  South          250000.0        1000
# 104  South          133000.0         950
# 105  South          149625.0         950

# %%
# Conditional slicing (that fits certain conditions)
# pandas lets you filter data by conditions over row/column values.

df[df['Units Sold'] == 1025]
# Out:
#            Retailer  Retailer ID Invoice Date     Region           State  \
# 37      Foot Locker      1185732   2020-03-11  Northeast        New York
# 43      Foot Locker      1185732   2020-03-17  Northeast        New York
# 176       West Gear      1128299   2021-01-12       West      California
# 734     Foot Locker      1185732   2020-04-24  Southeast         Florida
# 2295    Foot Locker      1185732   2021-01-09  Southeast         Georgia
# 2343    Foot Locker      1185732   2021-09-05  Southeast  South Carolina
# 2409  Sports Direct      1185732   2021-08-03  Southeast  North Carolina
#
#                City                  Product  Price per Unit  Units Sold  \
# 37         New York  Men's Athletic Footwear            55.0        1025
# 43         New York  Men's Athletic Footwear            55.0        1025
# 176   San Francisco    Men's Street Footwear            60.0        1025
# 734           Miami    Men's Street Footwear            45.0        1025
# ...

# %%
# You can use a > operator to draw comparisons. 

df.loc[df['Units Sold'] > 1025, ['Region','Operating Profit']]
# Out:
#          Region  Operating Profit
# 0     Northeast          300000.0
# 6     Northeast          312500.0
# 12    Northeast          305000.0
# 18    Northeast          300000.0
# 24    Northeast          366000.0
# ...         ...               ...
# 2325  Southeast          259875.0
# 2331  Southeast          336375.0
# 2337  Southeast          329062.5
# 2361  Southeast          338625.0
# 2403  Southeast          273000.0
#
# [32 rows x 2 columns]

# %%
# Cleaning data using pandas 
# Data cleaning is one of the most common tasks in data science.
# pandas lets you preprocess data for any use, 
# including but not limited to training machine learning and deep learning models
# Let’s use the DataFrame df2 from earlier, having four missing values,
# to illustrate a few data cleaning use cases. As a reminder, 
#'s how you can see how many missing values are in a DataFrame.

df2.isnull().sum()
# Out:
# Retailer               0
# Retailer ID            0
# Invoice Date           0
# Region                 0
# State                  0
#                     ...
# Total Sales            0
# Operating Profit       0
# Operating Margin       0
# Sales Method           0
# Pregnancies         9648
# Length: 14, dtype: int64

# %%
# Dealing with missing data technique
# 1: Dropping missing values

# One way to deal with missing data is to drop it.
# This is particularly useful in cases where you have plenty of data and losing a small portion
# won’t impact the downstream analysis. You can use a .
# dropna() method as shown below. Here, we are saving the results from .dropna() into a DataFrame df3.

df3 = df2.copy()
df3 = df3.dropna()
df3.shape
# Out:
# (0, 14)

# %%
# The axis argument lets you specify whether you are dropping rows,
# or columns, with missing values. The default axis removes the rows containing NaNs. 
# Use axis = 1 to remove the columns with one or more NaN values. 
# Also, notice how we are using the argument inplace=True which lets you skip saving the output of .
# dropna() into a new DataFrame.  

df3 = df2.copy()
df3.dropna(inplace=True, axis=1)
df3.head()
# Out:
#       Retailer  Retailer ID Invoice Date     Region     State      City  \
# 0  Foot Locker      1185732   2020-01-01  Northeast  New York  New York
# 1  Foot Locker      1185732   2020-01-02  Northeast  New York  New York
# 2  Foot Locker      1185732   2020-01-03  Northeast  New York  New York
# 3  Foot Locker      1185732   2020-01-04  Northeast  New York  New York
# 4  Foot Locker      1185732   2020-01-05  Northeast  New York  New York
#
#                      Product  Price per Unit  Units Sold  Total Sales  \
# 0      Men's Street Footwear            50.0        1200     600000.0
# 1    Men's Athletic Footwear            50.0        1000     500000.0
# 2    Women's Street Footwear            40.0        1000     400000.0
# 3  Women's Athletic Footwear            45.0         850     382500.0
# 4              Men's Apparel            60.0         900     540000.0
#
#    Operating Profit  Operating Margin Sales Method
# 0          300000.0              0.50     In-store
# ...

# %%
# Data analysis in pandas
# Summary operators (mean, mode, median)
# As you saw earlier, you can get the mean of each column value using the .mean() method.

df.mean()
# Out:
# C:\Users\NOUR SOFT\AppData\Local\Temp\ipykernel_948\3477955454.py:5: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.mean()
# C:\Users\NOUR SOFT\AppData\Local\Temp\ipykernel_948\3477955454.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Retailer ID         1.173850e+06
# Price per Unit      4.521663e+01
# Units Sold          2.569300e+02
# Total Sales         9.327344e+04
# Operating Profit    3.442524e+04
# Operating Margin    4.229913e-01
# dtype: float64

# %%
# A mode can be computed similarly using the .mode() method. 

df.mode()
# Out:
#       Retailer  Retailer ID Invoice Date Region       State      City  \
# 0  Foot Locker    1185732.0   2021-01-17   West  California  Portland
# 1          NaN          NaN          NaT    NaN       Texas       NaN
#
#                    Product  Price per Unit  Units Sold  Total Sales  \
# 0  Men's Athletic Footwear            50.0       225.0     100000.0
# 1    Men's Street Footwear             NaN         NaN          NaN
#
#    Operating Profit  Operating Margin Sales Method
# 0           21000.0              0.35       Online
# 1               NaN               NaN          NaN

# %%
# Similarly, the median of each column is computed with the .median() method

df.median()
# Out:
# C:\Users\NOUR SOFT\AppData\Local\Temp\ipykernel_948\2931509338.py:3: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.median()
# C:\Users\NOUR SOFT\AppData\Local\Temp\ipykernel_948\2931509338.py:3: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# Retailer ID         1185732.00
# Price per Unit           45.00
# Units Sold              176.00
# Total Sales            9576.00
# Operating Profit       4371.42
# Operating Margin          0.41
# dtype: float64

# %%
# Counting using .value_counts()
# Often times you'll work with categorical values,
# and you'll want to count the number of observations each category has in a column.
# Category values can be counted using the .value_counts() methods.

df['Retailer'].value_counts()
# Out:
# Foot Locker      2637
# West Gear        2374
# Sports Direct    2032
# Kohl's           1030
# Amazon            949
# Walmart           626
# Name: Retailer, dtype: int64

# %%
# Aggregating data with .groupby() in pandas

df.groupby('Retailer').mean()
# Out:
# C:\Users\NOUR SOFT\AppData\Local\Temp\ipykernel_948\1220208090.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Retailer').mean()
#                 Retailer ID  Price per Unit  Units Sold    Total Sales  \
# Retailer
# Amazon         1.185732e+06       48.759747  208.630137   81874.512118
# Foot Locker    1.174993e+06       44.784983  229.188093   83464.057641
# Kohl's         1.177071e+06       44.608738  279.004854   99140.536893
# Sports Direct  1.182488e+06       42.046752  274.429134   89798.718996
# Walmart        1.173732e+06       47.183706  329.432907  119102.891374
# West Gear      1.159070e+06       46.737995  263.379107  102343.863943
#
#                Operating Profit  Operating Margin
# Retailer
# Amazon             30367.232150          0.417871
# ...

# %%
#.groupby() enables grouping by more than one column by passing a list of column names, 
#as shown below.

df.groupby(['Retailer', 'Region']).mean()
# Out:
# C:\Users\NOUR SOFT\AppData\Local\Temp\ipykernel_948\2496405080.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['Retailer', 'Region']).mean()
#                       Retailer ID  Price per Unit  Units Sold    Total Sales  \
# Retailer  Region
# Amazon    Midwest    1.185732e+06       43.176471  330.330882  123793.183824
#           Northeast  1.185732e+06       49.395564  175.637708   67028.817006
#           South      1.185732e+06       32.333333  139.500000   34090.916667
#           Southeast  1.185732e+06       43.343284  221.059701   80793.529851
#           West       1.185732e+06       59.380952  212.293651  106071.626984
# ...                           ...             ...         ...            ...
# ...

# %%
# Line plots in pandas
# pandas enables you to chart out the relationships 
# among variables using line plots.

# %%
df[['Total Sales', 'Operating Profit']].plot.line()
# Out:
# <Axes: >

# %%
df[['Total Sales', 'Operating Profit']].plot.line(figsize=(20, 10), 
                                 color={"Total Sales": "red", "Operating Profit": "blue"})
# Out:
# <Axes: >

# %%
# All the columns of df can also be plotted on different 
# scales and axes by using the subplots argument.

df.plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >], dtype=object)

# %%
# Bar plots in pandas

# For discrete columns, you can use a bar plot over the category counts to
# visualize their distribution

df['Retailer'].value_counts().plot.bar()
# Out:
# <Axes: >
